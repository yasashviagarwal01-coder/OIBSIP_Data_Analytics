# %% [markdown]
# # Oasis Infobyte Internship
#
# ## Task 1: Exploratory Data Analysis (EDA) on Retail Sales Data
#
# ### Submitted by: Yashasvi Agarwal

# %%
# !pip install xlrd

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %% [markdown]
# ## 2. Load the Dataset

# %%
data = pd.read_excel("/content/sample_-_superstore.xls")

# %% [markdown]
# ## 3. Display First Five Rows

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03 2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05 2023-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %% [markdown]
# ### Observation
#
# - The first five rows provide a quick preview of the dataset.
# - The dataset contains customer details, product information, sales, profit, discount, quantity, and shipping details.
# - This helps in understanding the structure and contents of the dataset before performing further analysis.

# %% [markdown]
# ### 4. Dataset Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %% [markdown]
# ### Observation
#
# - The dataset contains **10,194 rows** and **21 columns**.
# - There are no missing values in any column.
# - The dataset contains both numerical and categorical features.
# - The data is clean and ready for further analysis.

# %% [markdown]
# ## 5. Dataset Shape

# %%
print("Dataset Shape:", data.shape)
# Out:
# Dataset Shape: (10194, 21)

# %% [markdown]
# ### Observation
#
# - The dataset consists of **10,194 rows** and **21 columns**.
# - A large number of records ensures meaningful analysis.
# - The dataset has sufficient features to perform comprehensive exploratory data analysis.

# %% [markdown]
# ## 6.checking missing value

# %%
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# ### Observation
#
# - The dataset contains **10,194 rows** and **21 columns**.
# - There are **no missing values** in any column.
# - The dataset contains both numerical and categorical features.
# - The data is clean and ready for analysis.

# %% [markdown]
# ##

# %% [markdown]
# ## 7.checking duplicaticate rows

# %%
print("Duplicate Rows:", data.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %% [markdown]
# ## 8. Statistical Summary

# %%
data.describe()
# Out:
#              Row ID                     Order Date  \
# count  10194.000000                          10194
# mean    5097.500000  2025-04-29 11:48:25.002942720
# min        1.000000            2023-01-03 00:00:00
# 25%     2549.250000            2024-05-14 00:00:00
# 50%     5097.500000            2025-06-25 00:00:00
# 75%     7645.750000            2026-05-14 00:00:00
# max    10194.000000            2026-12-30 00:00:00
# std     2942.898656                            NaN
#
#                            Ship Date         Sales      Quantity  \
# count                          10194  10194.000000  10194.000000
# mean   2025-05-03 10:52:45.626839296    228.225854      3.791838
# min              2023-01-07 00:00:00      0.444000      1.000000
# 25%              2024-05-19 00:00:00     17.220000      2.000000
# 50%              2025-06-28 00:00:00     53.910000      3.000000
# 75%              2026-05-18 00:00:00    209.500000      5.000000
# ...

# %% [markdown]
# ### Observation
#
# - The dataset contains **10,194 records**.
# - The average sales per order are **228.23**.
# - The average profit per order is **28.67**.
# - The maximum sales value is **22,638.48**, while the minimum sales value is **0.44**.
# - The minimum profit is **-6599.98**, showing that some orders resulted in heavy losses.
# - The discount ranges from **0% to 80%**.

# %% [markdown]
# ### Business Insight
#
# The company should investigate orders with very high losses and review its discount strategy to improve profitability.

# %% [markdown]
# ## 9. Total Sales

# %%
print("Total Sales:", data["Sales"].sum())
# Out:
# Total Sales: 2326534.3543

# %% [markdown]
# ### Observation
#
# This value represents the total revenue generated from all orders in the dataset.

# %% [markdown]
# ## 10. Total Profit

# %%
print("Total Profit:", data["Profit"].sum())
# Out:
# Total Profit: 292296.8145999999

# %% [markdown]
# ### Observation
#
# The total profit indicates the overall earnings after deducting costs from sales.

# %% [markdown]
# ## 11. Category Distribution

# %%
data["Category"].value_counts()
# Out:
# Category
# Office Supplies    6128
# Furniture          2201
# Technology         1865
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Category", data=data)
plt.title("Number of Orders by Category")
plt.show()

# %% [markdown]
# ### Observation
#
# - Office Supplies has the highest number of orders.
# - Furniture is the second most ordered category.
# - Technology has the lowest number of orders.

# %% [markdown]
# ### Business Insight
#
# Office Supplies are purchased frequently, making them an important source of regular sales. Maintaining sufficient inventory for this category can help meet customer demand.

# %% [markdown]
# ## 12. Sales by Category

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="Category", y="Sales", data=data, estimator=sum)
plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# ### Observation
#
# - Technology generates the highest sales revenue.
# - Furniture contributes moderate sales.
# - Office Supplies have many orders but lower total sales than Technology.

# %% [markdown]
# ### Business Insight
#
# Technology products contribute significantly to revenue. The company should continue promoting this category while identifying ways to increase Furniture sales.

# %% [markdown]
# ## 13. Profit by Category

# %%
plt.figure(figsize=(8,5))

sns.barplot(x="Category", y="Profit", data=data, estimator=sum)

plt.title("Total Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit")

plt.show()

# %% [markdown]
# ### Observation
#
# - Technology category generates the highest total profit.
# - Office Supplies is the second most profitable category.
# - Furniture contributes the lowest profit among all categories.

# %% [markdown]
# ### Business Insight
#
# Technology products are the most profitable for the company. The Furniture category should be analyzed to improve profitability by reducing discounts or optimizing pricing.

# %% [markdown]
# ## 14. Sales by Region

# %%
plt.figure(figsize=(8,5))

sns.barplot(x="Region", y="Sales", data=data, estimator=sum)

plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.show()

# %% [markdown]
# ### Observation
#
# - West region records the highest total sales.
# - East

# %% [markdown]
# ### Business Insight
#
# The West region is the highest revenue-generating region and its successful strategies can be adopted in other regions. The South region requires targeted marketing campaigns and sales strategies to improve its overall performance.

# %% [markdown]
# ## 15. Profit by Region

# %%
plt.figure(figsize=(8,5))

sns.barplot(x="Region", y="Profit", data=data, estimator=sum)

plt.title("Total Profit by Region")
plt.xlabel("Region")
plt.ylabel("Total Profit")

plt.show()

# %% [markdown]
# ### Observation
#
# - Some regions are more profitable than others.
# - High sales do not always result in high profits.
# - Regional profitability differs due to factors like discounts and product mix.

# %% [markdown]
# ### Business Insight
#
# Management should focus on improving profit margins in regions where sales are high but profits are comparatively low.

# %% [markdown]
# ## 16. Monthly Sales Trend

# %%
monthly_sales = data.groupby(data["Order Date"].dt.month)["Sales"].sum()

plt.figure(figsize=(10,5))

monthly_sales.plot(marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid(True)

plt.show()

# %% [markdown]
# ### Observation
#
# - Monthly sales fluctuate throughout the year.
# - Some months experience higher sales than others.
# - This indicates the presence of seasonal demand.

# %% [markdown]
# ### Business Insight
#
# The company can plan promotions and inventory based on high-demand months to maximize sales and customer satisfaction.

# %% [markdown]
# ## 17. Top 10 Best Selling Products

# %%
top_products = data.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)

top_products
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12,6))

sns.barplot(x=top_products.values,
            y=top_products.index)

plt.title("Top 10 Best Selling Products")
plt.xlabel("Total Sales")
plt.ylabel("Product Name")

plt.show()

# %% [markdown]
# ### Observation
#
# - The top 10 products contribute significantly to the overall sales.
# - A few products generate much higher sales than the remaining products.
# - Sales are concentrated among the best-selling products.

# %% [markdown]
# ### Business Insight
#
# The company should ensure adequate inventory for the best-selling products and use targeted marketing to further increase their sales.

# %% [markdown]
# ## 18. Top 10 Most Profitable Products

# %%
top_profit = data.groupby("Product Name")["Profit"].sum().sort_values(ascending=False).head(10)

top_profit
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     7753.0390
# Hewlett Packard LaserJet 3310 Copier                                            6983.8836
# Canon PC1060 Personal Laser Copier                                              4570.9347
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                       4094.9766
# Ativa V4110MDD Micro-Cut Shredder                                               3772.9461
# 3D Systems Cube Printer, 2nd Generation, Magenta                                3717.9714
# Plantronics Savi W720 Multi-Device Wireless Headset System                      3696.2820
# Ibico EPK-21 Electric Binding System                                            3345.2823
# Zebra ZM400 Thermal Label Printer                                               3343.5360
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(12,6))

sns.barplot(x=top_profit.values,
            y=top_profit.index)

plt.title("Top 10 Most Profitable Products")
plt.xlabel("Total Profit")
plt.ylabel("Product Name")

plt.show()

# %% [markdown]
# ### Observation
#
# - A small number of products contribute the highest profits.
# - Profit generation is concentrated among a few products.
# - These products are the company's strongest profit drivers.

# %% [markdown]
# ## 19. Sales by Customer Segment

# %% [markdown]
# plt.figure(figsize=(8,5))
#
# sns.barplot(x="Segment", y="Sales", data=data, estimator=sum)
#
# plt.title("Total Sales by Customer Segment")
# plt.xlabel("Customer Segment")
# plt.ylabel("Total Sales")
#
# plt.show()

# %% [markdown]
# ### Observation
#
# - Sales vary across different customer segments.
# - Some customer segments contribute more revenue than others.
# - Customer purchasing behavior differs among segments.

# %% [markdown]
# ### Business Insight
#
# The company should focus on high-performing customer segments while designing promotional strategies to improve sales among lower-performing segments.

# %% [markdown]
# ## 20. Correlation Heatmap

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    data[["Sales", "Profit", "Quantity", "Discount"]].corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ### Observation
#
# - Sales and Profit show a positive correlation.
# - Discount negatively impacts Profit.
# - Quantity has a weak relationship with Sales and Profit.

# %% [markdown]
# ### Business Insight
#
# The company should carefully manage discount policies because higher discounts tend to reduce profitability. Increasing sales while maintaining healthy profit margins will improve overall business performance.

# %% [markdown]
# ## 21. Sales by Ship Mode

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="Ship Mode", y="Sales", data=data, estimator=sum)
plt.title("Sales by Ship Mode")
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ## Observation
#
# Different shipping modes contribute differently to total sales

# %% [markdown]
# ## 22. Profit by Sub-Category

# %%
plt.figure(figsize=(12,6))

subcategory_profit = data.groupby("Sub-Category")["Profit"].sum().sort_values()

subcategory_profit.plot(kind="barh")

plt.title("Profit by Sub-Category")

plt.show()

# %% [markdown]
# ## Observation
#
# Some sub-categories generate losses while others contribute significantly to profit.

# %% [markdown]
# # Final Conclusion
#
# - The dataset was successfully analyzed using Python.
# - Technology category generated the highest sales and profit.
# - West region performed best in terms of revenue and profitability.
# - Monthly sales showed seasonal variations.
# - Best-selling and most profitable products were identified.
# - Discount has a negative impact on profit.
# - Business insights were generated to help improve sales and profitability.

# %% [markdown]
# # Thank You
#
# Thank you for reviewing this project.
#
# This project was completed as part of the Oasis Infobyte Data Analytics Internship using Python, Pandas, Matplotlib, and Seaborn.
